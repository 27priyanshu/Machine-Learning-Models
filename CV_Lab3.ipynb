# %% [markdown]
# <a href="https://colab.research.google.com/github/27priyanshu/Machine-Learning-Models/blob/main/CV_Lab3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import cv2
from google.colab.patches import cv2_imshow

# %%
img= cv2.imread("/content/pandu.jpg")

# %%
img
# Out:
# array([[[ 34,  28,  33],
#         [ 44,  62,  69],
#         [ 18,  61,  70],
#         ...,
#         [ 90, 143,  76],
#         [ 95, 146,  79],
#         [ 99, 150,  83]],
#
#        [[ 72,  76,  77],
#         [ 54,  77,  79],
#         [ 17,  58,  61],
#         ...,
#         [ 86, 141,  78],
#         [ 91, 144,  81],
#         [ 95, 146,  84]],
#
#        [[ 76,  95,  92],
#         [ 45,  74,  71],
#         [ 11,  51,  46],
#         ...,
#         [ 80, 138,  79],
#         [ 84, 140,  81],
#         [ 86, 142,  83]],
#
#        ...,
#
#        [[ 51, 129,  75],
#         [ 54, 130,  76],
#         [ 56, 131,  77],
#         ...,
#         [ 61,  83,  59],
#         [ 61,  83,  59],
#         [ 61,  83,  59]],
#
#        [[ 53, 131,  77],
#         [ 56, 132,  78],
#         [ 58, 133,  79],
#         ...,
#         [ 62,  84,  60],
#         [ 62,  84,  60],
#         [ 62,  84,  60]],
#
#        [[ 55, 133,  79],
#         [ 57, 133,  79],
#         [ 60, 135,  81],
# ...

# %%
blur_image = cv2.GaussianBlur(img,(9,9),100)

# %% [markdown]
# Ques 1

# %%
cv2_imshow(blur_image)
# Out:
# <PIL.Image.Image image mode=RGB size=612x612>

# %% [markdown]
# Ques2

# %%
def invert_image(img):
  inverted_img = cv2.bitwise_not(img)
  return inverted_img

# %%
inverted_image = invert_image(img)
cv2_imshow(inverted_image)
cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# <PIL.Image.Image image mode=RGB size=612x612>

# %% [markdown]
# Ques 3

# %%
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

# %%
gray
# Out:
# array([[ 30,  62,  59, ..., 117, 120, 124],
#        [ 76,  75,  54, ..., 116, 119, 122],
#        [ 92,  70,  45, ..., 114, 116, 118],
#        ...,
#        [104, 105, 106, ...,  73,  73,  73],
#        [106, 107, 108, ...,  74,  74,  74],
#        [108, 108, 110, ...,  75,  75,  75]], dtype=uint8)

# %%
import numpy as np

mean = np.mean(gray)
mean
# Out:
# 89.4783523431159

# %%
gray=np.where(gray<=89,1,255)

# %%
gray
# Out:
# array([[  1,   1,   1, ..., 255, 255, 255],
#        [  1,   1,   1, ..., 255, 255, 255],
#        [  1,   1,   1, ..., 255, 255, 255],
#        ...,
#        [255, 255, 255, ...,   1,   1,   1],
#        [255, 255, 255, ...,   1,   1,   1],
#        [255, 255, 255, ...,   1,   1,   1]])

# %%
cv2_imshow(gray)
# Out:
# <PIL.Image.Image image mode=L size=612x612>

# %% [markdown]
# Ques 4

# %%
height, width = img.shape[:2]

quarter_height, quarter_width = 0, width / 4

T = np.float32([[1, 0, quarter_width], [0, 1, quarter_height]])


img_translation = cv2.warpAffine(img, T, (width, height))

cv2_imshow( img)
cv2_imshow( img_translation)
cv2.waitKey()
# Out:
# <PIL.Image.Image image mode=RGB size=612x612>
# <PIL.Image.Image image mode=RGB size=612x612>
# -1
